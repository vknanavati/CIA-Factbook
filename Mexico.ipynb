# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
df = pd.read_csv("Mexico_City_Hostels.csv", index_col=[0])
df.head()
df_copy = df.copy()

df_copy
# Out:
#    Casa Kanabrí Hostal Boutique  Hostal Juarez  Wanderlust District  \
# 0                            10            9.8                  9.9
# 1                            10            9.8                  9.8
# 2                            10            9.9                  9.8
# 3                            10            9.4                  9.8
# 4                            10            9.8                  9.7
# 5                            10            9.8                  9.6
# 6                            10            9.7                  9.5
#
#    Casa Pancha  Hostel Barrio Downtown Mexico City  U-Co Roma Coliving  \
# 0          9.9                                 9.7                 9.7
# 1          9.7                                 9.4                 9.9
# 2          9.7                                 9.6                 9.7
# 3          9.1                                 8.8                 8.5
# 4          9.9                                 9.7                 9.5
# 5          9.5                                 9.6                 9.3
# 6          9.5                                 9.7                 9.5
#
#    Casa Eufemia Hostel  Casa Pepe  Viajero CDMX Centro Hostel  \
# 0                  9.7        9.8                         9.6
# 1                  9.4        9.4                         9.2
# 2                  9.3        9.3                         9.5
# 3                  9.3        9.3                         9.2
# 4                  9.3        9.3                         9.6
# 5                  9.3        8.9                         9.2
# 6                  9.2        9.3                         9.2
#
#    Hostal Regina Centro Historico Ciudad de Mexico  ...  Hostal Emperador  \
# 0                                              9.6  ...               4.2
# 1                                              9.4  ...               5.2
# 2                                              9.9  ...               3.4
# 3                                              8.6  ...               2.2
# 4                                              9.3  ...               2.2
# 5                                              9.2  ...               2.8
# 6                                              8.8  ...               2.2
#
#    Casa Tamayo  Mala Vecindad Centro Historico  Bonsai Second Home  \
# 0           10                              10                  10
# 1           10                              10                   6
# 2           10                               9                  10
# 3           10                               8                   8
# 4            9                              10                   8
# 5            9                               9                  10
# 6           10                               9                  10
#
#    Ayenda Oasis Airport  Roomies Hostel Centro Medico  \
# 0                    10                           8.3
# 1                     8                           9.7
# 2                    10                           9.4
# 3                     8                           7.7
# 4                    10                           7.4
# 5                     8                           8.3
# 6                     8                           7.4
#
#    Hotel Amigo Suites Downtown  Cadillac Boutique Hotel  Anys Hostal  \
# 0                          9.2                      8.7         10.0
# 1                          9.2                      7.3         10.0
# 2                          9.2                      9.3         10.0
# 3                          6.4                      5.3         10.0
# 4                          8.0                     10.0         10.0
# 5                          7.6                      4.7         10.0
# 6                          6.8                      7.3          9.6
#
#    B&B Mexico Roma Norte
# 0                    9.8
# 1                    9.8
# 2                    9.3
# 3                    8.2
# 4                    9.3
# 5                    8.6
# 6                    7.8
#
# [7 rows x 46 columns]

# %%
new_df = df_copy.T.reset_index()
new_df
# Out:
#                                               index     0     1     2     3  \
# 0                      Casa Kanabrí Hostal Boutique  10.0  10.0  10.0  10.0
# 1                                     Hostal Juarez   9.8   9.8   9.9   9.4
# 2                               Wanderlust District   9.9   9.8   9.8   9.8
# 3                                       Casa Pancha   9.9   9.7   9.7   9.1
# 4                Hostel Barrio Downtown Mexico City   9.7   9.4   9.6   8.8
# 5                                U-Co Roma Coliving   9.7   9.9   9.7   8.5
# 6                               Casa Eufemia Hostel   9.7   9.4   9.3   9.3
# 7                                         Casa Pepe   9.8   9.4   9.3   9.3
# 8                        Viajero CDMX Centro Hostel   9.6   9.2   9.5   9.2
# 9   Hostal Regina Centro Historico Ciudad de Mexico   9.6   9.4   9.9   8.6
# 10                            Hostal Cuija Coyoacan   9.7   9.7   9.1   8.7
# 11                             Fungi Hostal Condesa   9.2   9.8   9.0   8.1
# 12                                      U-Co Juarez   9.0   9.5   9.5   9.0
# 13                             Massiosare El Hostel   9.2   9.3   9.2   8.9
# 14                                      Hostel Home   9.5   9.7   9.2   8.8
# 15                                 Suites DF Hostel   9.3   9.1   9.0   8.7
# 16                               Mexico City Hostel   9.1   9.6   8.5   7.6
# 17                                     HoM Balderas   8.9   9.0   9.1   7.6
# 18                         Hostel Airport Mexico DF   8.1   8.7   8.7   8.0
# 19                      Hostel Mundo Joven Catedral   9.3   9.7   8.8   7.1
# 20                                  CASA MX alameda   9.1   8.5   8.7   7.7
# 21                       Capsule Hostel Mexico City   8.9   9.4   8.7   6.7
# 22                            Metro Hostal Boutique   8.6   9.6   8.0   7.5
# 23                                    Downtown Beds   9.2   9.5   7.5   6.7
# 24                                   CASA MX centro   8.9   9.3   8.1   6.3
# 25                                    HoM Monterrey   9.3   9.3   8.4   6.7
# 26                      Selina Mexico City Downtown   8.8   7.8   7.6   7.4
# 27                                   Mexiqui Zocalo   8.8   8.6   7.9   6.9
# 28                                     Hostel Amigo   8.1   9.2   8.2   5.9
# 29                           Roomies Hostel Condesa   9.0   9.0   8.4   5.8
# 30                              Roomies Hostel Roma   7.3   9.4   7.7   6.1
# 31                     Roomies Hostal Parque Mexico   7.4   8.9   7.5   5.9
# 32                                     Roma Norte 6   7.9   9.1   7.4   6.3
# 33                       Hostel Condesa Chapultepec   7.3   7.8   7.0   6.3
# 34                            YWCA Centro Historico   7.4   7.8   8.2   5.8
# 35                   Mala Vecindad Beer Hostel CDMX   6.8   5.2   7.6   4.4
# 36                                 Hostal Emperador   4.2   5.2   3.4   2.2
# 37                                      Casa Tamayo  10.0  10.0  10.0  10.0
# 38                   Mala Vecindad Centro Historico  10.0  10.0   9.0   8.0
# 39                               Bonsai Second Home  10.0   6.0  10.0   8.0
# 40                             Ayenda Oasis Airport  10.0   8.0  10.0   8.0
# 41                     Roomies Hostel Centro Medico   8.3   9.7   9.4   7.7
# 42                      Hotel Amigo Suites Downtown   9.2   9.2   9.2   6.4
# 43                          Cadillac Boutique Hotel   8.7   7.3   9.3   5.3
# 44                                      Anys Hostal  10.0  10.0  10.0  10.0
# 45                            B&B Mexico Roma Norte   9.8   9.8   9.3   8.2
#
#        4     5     6
# 0   10.0  10.0  10.0
# 1    9.8   9.8   9.7
# 2    9.7   9.6   9.5
# 3    9.9   9.5   9.5
# 4    9.7   9.6   9.7
# 5    9.5   9.3   9.5
# 6    9.3   9.3   9.2
# 7    9.3   8.9   9.3
# 8    9.6   9.2   9.2
# 9    9.3   9.2   8.8
# 10   8.9   9.1   8.9
# 11   9.4   9.1   8.8
# 12   8.8   8.7   8.5
# 13   8.9   8.9   8.5
# 14   8.5   8.6   7.9
# 15   8.8   8.9   8.3
# 16   9.5   8.9   8.7
# 17   8.7   8.9   7.9
# 18   8.9   8.4   8.4
# 19   8.1   8.0   7.8
# 20   7.9   8.6   8.0
# 21   7.5   7.9   6.8
# 22   7.1   7.8   7.3
# 23   8.1   7.7   6.8
# 24   7.5   7.5   7.2
# 25   7.1   7.9   5.7
# 26   7.4   7.4   7.6
# 27   7.4   7.3   7.1
# 28   7.1   7.5   6.6
# 29   6.6   7.0   6.2
# 30   5.7   6.8   5.7
# 31   6.2   6.6   5.9
# 32   6.1   6.0   5.3
# 33   6.0   6.8   5.8
# 34   6.0   6.6   4.8
# 35   6.4   6.0   6.0
# 36   2.2   2.8   2.2
# 37   9.0   9.0  10.0
# 38  10.0   9.0   9.0
# 39   8.0  10.0  10.0
# 40  10.0   8.0   8.0
# 41   7.4   8.3   7.4
# 42   8.0   7.6   6.8
# 43  10.0   4.7   7.3
# 44  10.0  10.0   9.6
# 45   9.3   8.6   7.8

# %%
# new_df.set_axis(['Security', 'Location', 'Staff', 'Atmosphere', 'Cleanliness', 'Value for Money', 'Facilities'], axis=1, copy=True)
new_df = new_df.set_axis([' ', 'Security', 'Location', 'Staff', 'Atmosphere', 'Cleanliness', 'Value for Money', 'Facilities'], axis=1, copy=True)
new_df= new_df.head(30)
new_df
# Out:
#                                                      Security  Location  \
# 0                      Casa Kanabrí Hostal Boutique      10.0      10.0
# 1                                     Hostal Juarez       9.8       9.8
# 2                               Wanderlust District       9.9       9.8
# 3                                       Casa Pancha       9.9       9.7
# 4                Hostel Barrio Downtown Mexico City       9.7       9.4
# 5                                U-Co Roma Coliving       9.7       9.9
# 6                               Casa Eufemia Hostel       9.7       9.4
# 7                                         Casa Pepe       9.8       9.4
# 8                        Viajero CDMX Centro Hostel       9.6       9.2
# 9   Hostal Regina Centro Historico Ciudad de Mexico       9.6       9.4
# 10                            Hostal Cuija Coyoacan       9.7       9.7
# 11                             Fungi Hostal Condesa       9.2       9.8
# 12                                      U-Co Juarez       9.0       9.5
# 13                             Massiosare El Hostel       9.2       9.3
# 14                                      Hostel Home       9.5       9.7
# 15                                 Suites DF Hostel       9.3       9.1
# 16                               Mexico City Hostel       9.1       9.6
# 17                                     HoM Balderas       8.9       9.0
# 18                         Hostel Airport Mexico DF       8.1       8.7
# 19                      Hostel Mundo Joven Catedral       9.3       9.7
# 20                                  CASA MX alameda       9.1       8.5
# 21                       Capsule Hostel Mexico City       8.9       9.4
# 22                            Metro Hostal Boutique       8.6       9.6
# 23                                    Downtown Beds       9.2       9.5
# 24                                   CASA MX centro       8.9       9.3
# 25                                    HoM Monterrey       9.3       9.3
# 26                      Selina Mexico City Downtown       8.8       7.8
# 27                                   Mexiqui Zocalo       8.8       8.6
# 28                                     Hostel Amigo       8.1       9.2
# 29                           Roomies Hostel Condesa       9.0       9.0
#
#     Staff  Atmosphere  Cleanliness  Value for Money  Facilities
# 0    10.0        10.0         10.0             10.0        10.0
# 1     9.9         9.4          9.8              9.8         9.7
# 2     9.8         9.8          9.7              9.6         9.5
# 3     9.7         9.1          9.9              9.5         9.5
# 4     9.6         8.8          9.7              9.6         9.7
# 5     9.7         8.5          9.5              9.3         9.5
# 6     9.3         9.3          9.3              9.3         9.2
# 7     9.3         9.3          9.3              8.9         9.3
# 8     9.5         9.2          9.6              9.2         9.2
# 9     9.9         8.6          9.3              9.2         8.8
# 10    9.1         8.7          8.9              9.1         8.9
# 11    9.0         8.1          9.4              9.1         8.8
# 12    9.5         9.0          8.8              8.7         8.5
# 13    9.2         8.9          8.9              8.9         8.5
# 14    9.2         8.8          8.5              8.6         7.9
# 15    9.0         8.7          8.8              8.9         8.3
# 16    8.5         7.6          9.5              8.9         8.7
# 17    9.1         7.6          8.7              8.9         7.9
# 18    8.7         8.0          8.9              8.4         8.4
# 19    8.8         7.1          8.1              8.0         7.8
# 20    8.7         7.7          7.9              8.6         8.0
# 21    8.7         6.7          7.5              7.9         6.8
# 22    8.0         7.5          7.1              7.8         7.3
# 23    7.5         6.7          8.1              7.7         6.8
# 24    8.1         6.3          7.5              7.5         7.2
# 25    8.4         6.7          7.1              7.9         5.7
# 26    7.6         7.4          7.4              7.4         7.6
# 27    7.9         6.9          7.4              7.3         7.1
# 28    8.2         5.9          7.1              7.5         6.6
# 29    8.4         5.8          6.6              7.0         6.2

# %%
new_df['mean'] = df.iloc[:,1:].mean(axis=1)
new_df
# Out:
#                                                      Security  Location  \
# 0                      Casa Kanabrí Hostal Boutique      10.0      10.0
# 1                                     Hostal Juarez       9.8       9.8
# 2                               Wanderlust District       9.9       9.8
# 3                                       Casa Pancha       9.9       9.7
# 4                Hostel Barrio Downtown Mexico City       9.7       9.4
# 5                                U-Co Roma Coliving       9.7       9.9
# 6                               Casa Eufemia Hostel       9.7       9.4
# 7                                         Casa Pepe       9.8       9.4
# 8                        Viajero CDMX Centro Hostel       9.6       9.2
# 9   Hostal Regina Centro Historico Ciudad de Mexico       9.6       9.4
# 10                            Hostal Cuija Coyoacan       9.7       9.7
# 11                             Fungi Hostal Condesa       9.2       9.8
# 12                                      U-Co Juarez       9.0       9.5
# 13                             Massiosare El Hostel       9.2       9.3
# 14                                      Hostel Home       9.5       9.7
# 15                                 Suites DF Hostel       9.3       9.1
# 16                               Mexico City Hostel       9.1       9.6
# 17                                     HoM Balderas       8.9       9.0
# 18                         Hostel Airport Mexico DF       8.1       8.7
# 19                      Hostel Mundo Joven Catedral       9.3       9.7
# 20                                  CASA MX alameda       9.1       8.5
# 21                       Capsule Hostel Mexico City       8.9       9.4
# 22                            Metro Hostal Boutique       8.6       9.6
# 23                                    Downtown Beds       9.2       9.5
# 24                                   CASA MX centro       8.9       9.3
# 25                                    HoM Monterrey       9.3       9.3
# 26                      Selina Mexico City Downtown       8.8       7.8
# 27                                   Mexiqui Zocalo       8.8       8.6
# 28                                     Hostel Amigo       8.1       9.2
# 29                           Roomies Hostel Condesa       9.0       9.0
#
#     Staff  Atmosphere  Cleanliness  Value for Money  Facilities      mean
# 0    10.0        10.0         10.0             10.0        10.0  8.933333
# 1     9.9         9.4          9.8              9.8         9.7  8.971111
# 2     9.8         9.8          9.7              9.6         9.5  8.740000
# 3     9.7         9.1          9.9              9.5         9.5  7.571111
# 4     9.6         8.8          9.7              9.6         9.7  8.191111
# 5     9.7         8.5          9.5              9.3         9.5  8.117778
# 6     9.3         9.3          9.3              9.3         9.2  7.755556
# 7     9.3         9.3          9.3              8.9         9.3       NaN
# 8     9.5         9.2          9.6              9.2         9.2       NaN
# 9     9.9         8.6          9.3              9.2         8.8       NaN
# 10    9.1         8.7          8.9              9.1         8.9       NaN
# 11    9.0         8.1          9.4              9.1         8.8       NaN
# 12    9.5         9.0          8.8              8.7         8.5       NaN
# 13    9.2         8.9          8.9              8.9         8.5       NaN
# 14    9.2         8.8          8.5              8.6         7.9       NaN
# 15    9.0         8.7          8.8              8.9         8.3       NaN
# 16    8.5         7.6          9.5              8.9         8.7       NaN
# 17    9.1         7.6          8.7              8.9         7.9       NaN
# 18    8.7         8.0          8.9              8.4         8.4       NaN
# 19    8.8         7.1          8.1              8.0         7.8       NaN
# 20    8.7         7.7          7.9              8.6         8.0       NaN
# 21    8.7         6.7          7.5              7.9         6.8       NaN
# 22    8.0         7.5          7.1              7.8         7.3       NaN
# 23    7.5         6.7          8.1              7.7         6.8       NaN
# 24    8.1         6.3          7.5              7.5         7.2       NaN
# 25    8.4         6.7          7.1              7.9         5.7       NaN
# 26    7.6         7.4          7.4              7.4         7.6       NaN
# 27    7.9         6.9          7.4              7.3         7.1       NaN
# 28    8.2         5.9          7.1              7.5         6.6       NaN
# 29    8.4         5.8          6.6              7.0         6.2       NaN

# %%
df.shape
# Out:
# (7, 46)

# %%
df_test = df_copy.set_axis(['Security', 'Location', 'Staff', 'Atmosphere', 'Cleanliness', 'Value for Money', 'Facilities'], axis=0, copy=True)

# %%
# df_copy.mean(axis=0)

# %%
df_test.loc['avg']= df.mean()
df_test
# Out:
#                  Casa Kanabrí Hostal Boutique  Hostal Juarez  \
# Security                                 10.0       9.800000
# Location                                 10.0       9.800000
# Staff                                    10.0       9.900000
# Atmosphere                               10.0       9.400000
# Cleanliness                              10.0       9.800000
# Value for Money                          10.0       9.800000
# Facilities                               10.0       9.700000
# avg                                      10.0       9.742857
#
#                  Wanderlust District  Casa Pancha  \
# Security                    9.900000     9.900000
# Location                    9.800000     9.700000
# Staff                       9.800000     9.700000
# Atmosphere                  9.800000     9.100000
# Cleanliness                 9.700000     9.900000
# Value for Money             9.600000     9.500000
# Facilities                  9.500000     9.500000
# avg                         9.728571     9.614286
#
#                  Hostel Barrio Downtown Mexico City  U-Co Roma Coliving  \
# Security                                        9.7            9.700000
# Location                                        9.4            9.900000
# Staff                                           9.6            9.700000
# Atmosphere                                      8.8            8.500000
# Cleanliness                                     9.7            9.500000
# Value for Money                                 9.6            9.300000
# Facilities                                      9.7            9.500000
# avg                                             9.5            9.442857
#
#                  Casa Eufemia Hostel  Casa Pepe  Viajero CDMX Centro Hostel  \
# Security                    9.700000   9.800000                    9.600000
# Location                    9.400000   9.400000                    9.200000
# Staff                       9.300000   9.300000                    9.500000
# Atmosphere                  9.300000   9.300000                    9.200000
# Cleanliness                 9.300000   9.300000                    9.600000
# Value for Money             9.300000   8.900000                    9.200000
# Facilities                  9.200000   9.300000                    9.200000
# avg                         9.357143   9.328571                    9.357143
#
#                  Hostal Regina Centro Historico Ciudad de Mexico  ...  \
# Security                                                9.600000  ...
# Location                                                9.400000  ...
# Staff                                                   9.900000  ...
# Atmosphere                                              8.600000  ...
# Cleanliness                                             9.300000  ...
# Value for Money                                         9.200000  ...
# Facilities                                              8.800000  ...
# avg                                                     9.257143  ...
#
#                  Hostal Emperador  Casa Tamayo  \
# Security                 4.200000    10.000000
# Location                 5.200000    10.000000
# Staff                    3.400000    10.000000
# Atmosphere               2.200000    10.000000
# Cleanliness              2.200000     9.000000
# Value for Money          2.800000     9.000000
# Facilities               2.200000    10.000000
# avg                      3.171429     9.714286
#
#                  Mala Vecindad Centro Historico  Bonsai Second Home  \
# Security                              10.000000           10.000000
# Location                              10.000000            6.000000
# Staff                                  9.000000           10.000000
# Atmosphere                             8.000000            8.000000
# Cleanliness                           10.000000            8.000000
# Value for Money                        9.000000           10.000000
# Facilities                             9.000000           10.000000
# avg                                    9.285714            8.857143
#
#                  Ayenda Oasis Airport  Roomies Hostel Centro Medico  \
# Security                    10.000000                      8.300000
# Location                     8.000000                      9.700000
# Staff                       10.000000                      9.400000
# Atmosphere                   8.000000                      7.700000
# Cleanliness                 10.000000                      7.400000
# Value for Money              8.000000                      8.300000
# Facilities                   8.000000                      7.400000
# avg                          8.857143                      8.314286
#
#                  Hotel Amigo Suites Downtown  Cadillac Boutique Hotel  \
# Security                            9.200000                 8.700000
# Location                            9.200000                 7.300000
# Staff                               9.200000                 9.300000
# Atmosphere                          6.400000                 5.300000
# Cleanliness                         8.000000                10.000000
# Value for Money                     7.600000                 4.700000
# Facilities                          6.800000                 7.300000
# avg                                 8.057143                 7.514286
#
#                  Anys Hostal  B&B Mexico Roma Norte
# Security           10.000000               9.800000
# Location           10.000000               9.800000
# Staff              10.000000               9.300000
# Atmosphere         10.000000               8.200000
# Cleanliness        10.000000               9.300000
# Value for Money    10.000000               8.600000
# Facilities          9.600000               7.800000
# avg                 9.942857               8.971429
#
# [8 rows x 46 columns]

# %%
df3 = df_test.T.reset_index()
df3
# Out:
#                                               index  Security  Location  \
# 0                      Casa Kanabrí Hostal Boutique      10.0      10.0
# 1                                     Hostal Juarez       9.8       9.8
# 2                               Wanderlust District       9.9       9.8
# 3                                       Casa Pancha       9.9       9.7
# 4                Hostel Barrio Downtown Mexico City       9.7       9.4
# 5                                U-Co Roma Coliving       9.7       9.9
# 6                               Casa Eufemia Hostel       9.7       9.4
# 7                                         Casa Pepe       9.8       9.4
# 8                        Viajero CDMX Centro Hostel       9.6       9.2
# 9   Hostal Regina Centro Historico Ciudad de Mexico       9.6       9.4
# 10                            Hostal Cuija Coyoacan       9.7       9.7
# 11                             Fungi Hostal Condesa       9.2       9.8
# 12                                      U-Co Juarez       9.0       9.5
# 13                             Massiosare El Hostel       9.2       9.3
# 14                                      Hostel Home       9.5       9.7
# 15                                 Suites DF Hostel       9.3       9.1
# 16                               Mexico City Hostel       9.1       9.6
# 17                                     HoM Balderas       8.9       9.0
# 18                         Hostel Airport Mexico DF       8.1       8.7
# 19                      Hostel Mundo Joven Catedral       9.3       9.7
# 20                                  CASA MX alameda       9.1       8.5
# 21                       Capsule Hostel Mexico City       8.9       9.4
# 22                            Metro Hostal Boutique       8.6       9.6
# 23                                    Downtown Beds       9.2       9.5
# 24                                   CASA MX centro       8.9       9.3
# 25                                    HoM Monterrey       9.3       9.3
# 26                      Selina Mexico City Downtown       8.8       7.8
# 27                                   Mexiqui Zocalo       8.8       8.6
# 28                                     Hostel Amigo       8.1       9.2
# 29                           Roomies Hostel Condesa       9.0       9.0
# 30                              Roomies Hostel Roma       7.3       9.4
# 31                     Roomies Hostal Parque Mexico       7.4       8.9
# 32                                     Roma Norte 6       7.9       9.1
# 33                       Hostel Condesa Chapultepec       7.3       7.8
# 34                            YWCA Centro Historico       7.4       7.8
# 35                   Mala Vecindad Beer Hostel CDMX       6.8       5.2
# 36                                 Hostal Emperador       4.2       5.2
# 37                                      Casa Tamayo      10.0      10.0
# 38                   Mala Vecindad Centro Historico      10.0      10.0
# 39                               Bonsai Second Home      10.0       6.0
# 40                             Ayenda Oasis Airport      10.0       8.0
# 41                     Roomies Hostel Centro Medico       8.3       9.7
# 42                      Hotel Amigo Suites Downtown       9.2       9.2
# 43                          Cadillac Boutique Hotel       8.7       7.3
# 44                                      Anys Hostal      10.0      10.0
# 45                            B&B Mexico Roma Norte       9.8       9.8
#
#     Staff  Atmosphere  Cleanliness  Value for Money  Facilities        avg
# 0    10.0        10.0         10.0             10.0        10.0  10.000000
# 1     9.9         9.4          9.8              9.8         9.7   9.742857
# 2     9.8         9.8          9.7              9.6         9.5   9.728571
# 3     9.7         9.1          9.9              9.5         9.5   9.614286
# 4     9.6         8.8          9.7              9.6         9.7   9.500000
# 5     9.7         8.5          9.5              9.3         9.5   9.442857
# 6     9.3         9.3          9.3              9.3         9.2   9.357143
# 7     9.3         9.3          9.3              8.9         9.3   9.328571
# 8     9.5         9.2          9.6              9.2         9.2   9.357143
# 9     9.9         8.6          9.3              9.2         8.8   9.257143
# 10    9.1         8.7          8.9              9.1         8.9   9.157143
# 11    9.0         8.1          9.4              9.1         8.8   9.057143
# 12    9.5         9.0          8.8              8.7         8.5   9.000000
# 13    9.2         8.9          8.9              8.9         8.5   8.985714
# 14    9.2         8.8          8.5              8.6         7.9   8.885714
# 15    9.0         8.7          8.8              8.9         8.3   8.871429
# 16    8.5         7.6          9.5              8.9         8.7   8.842857
# 17    9.1         7.6          8.7              8.9         7.9   8.585714
# 18    8.7         8.0          8.9              8.4         8.4   8.457143
# 19    8.8         7.1          8.1              8.0         7.8   8.400000
# 20    8.7         7.7          7.9              8.6         8.0   8.357143
# 21    8.7         6.7          7.5              7.9         6.8   7.985714
# 22    8.0         7.5          7.1              7.8         7.3   7.985714
# 23    7.5         6.7          8.1              7.7         6.8   7.928571
# 24    8.1         6.3          7.5              7.5         7.2   7.828571
# 25    8.4         6.7          7.1              7.9         5.7   7.771429
# 26    7.6         7.4          7.4              7.4         7.6   7.714286
# 27    7.9         6.9          7.4              7.3         7.1   7.714286
# 28    8.2         5.9          7.1              7.5         6.6   7.514286
# 29    8.4         5.8          6.6              7.0         6.2   7.428571
# 30    7.7         6.1          5.7              6.8         5.7   6.957143
# 31    7.5         5.9          6.2              6.6         5.9   6.914286
# 32    7.4         6.3          6.1              6.0         5.3   6.871429
# 33    7.0         6.3          6.0              6.8         5.8   6.714286
# 34    8.2         5.8          6.0              6.6         4.8   6.657143
# 35    7.6         4.4          6.4              6.0         6.0   6.057143
# 36    3.4         2.2          2.2              2.8         2.2   3.171429
# 37   10.0        10.0          9.0              9.0        10.0   9.714286
# 38    9.0         8.0         10.0              9.0         9.0   9.285714
# 39   10.0         8.0          8.0             10.0        10.0   8.857143
# 40   10.0         8.0         10.0              8.0         8.0   8.857143
# 41    9.4         7.7          7.4              8.3         7.4   8.314286
# 42    9.2         6.4          8.0              7.6         6.8   8.057143
# 43    9.3         5.3         10.0              4.7         7.3   7.514286
# 44   10.0        10.0         10.0             10.0         9.6   9.942857
# 45    9.3         8.2          9.3              8.6         7.8   8.971429

# %%
df_test
# Out:
#                  Casa Kanabrí Hostal Boutique  Hostal Juarez  \
# Security                                 10.0       9.800000
# Location                                 10.0       9.800000
# Staff                                    10.0       9.900000
# Atmosphere                               10.0       9.400000
# Cleanliness                              10.0       9.800000
# Value for Money                          10.0       9.800000
# Facilities                               10.0       9.700000
# avg                                      10.0       9.742857
#
#                  Wanderlust District  Casa Pancha  \
# Security                    9.900000     9.900000
# Location                    9.800000     9.700000
# Staff                       9.800000     9.700000
# Atmosphere                  9.800000     9.100000
# Cleanliness                 9.700000     9.900000
# Value for Money             9.600000     9.500000
# Facilities                  9.500000     9.500000
# avg                         9.728571     9.614286
#
#                  Hostel Barrio Downtown Mexico City  U-Co Roma Coliving  \
# Security                                        9.7            9.700000
# Location                                        9.4            9.900000
# Staff                                           9.6            9.700000
# Atmosphere                                      8.8            8.500000
# Cleanliness                                     9.7            9.500000
# Value for Money                                 9.6            9.300000
# Facilities                                      9.7            9.500000
# avg                                             9.5            9.442857
#
#                  Casa Eufemia Hostel  Casa Pepe  Viajero CDMX Centro Hostel  \
# Security                    9.700000   9.800000                    9.600000
# Location                    9.400000   9.400000                    9.200000
# Staff                       9.300000   9.300000                    9.500000
# Atmosphere                  9.300000   9.300000                    9.200000
# Cleanliness                 9.300000   9.300000                    9.600000
# Value for Money             9.300000   8.900000                    9.200000
# Facilities                  9.200000   9.300000                    9.200000
# avg                         9.357143   9.328571                    9.357143
#
#                  Hostal Regina Centro Historico Ciudad de Mexico  ...  \
# Security                                                9.600000  ...
# Location                                                9.400000  ...
# Staff                                                   9.900000  ...
# Atmosphere                                              8.600000  ...
# Cleanliness                                             9.300000  ...
# Value for Money                                         9.200000  ...
# Facilities                                              8.800000  ...
# avg                                                     9.257143  ...
#
#                  Hostal Emperador  Casa Tamayo  \
# Security                 4.200000    10.000000
# Location                 5.200000    10.000000
# Staff                    3.400000    10.000000
# Atmosphere               2.200000    10.000000
# Cleanliness              2.200000     9.000000
# Value for Money          2.800000     9.000000
# Facilities               2.200000    10.000000
# avg                      3.171429     9.714286
#
#                  Mala Vecindad Centro Historico  Bonsai Second Home  \
# Security                              10.000000           10.000000
# Location                              10.000000            6.000000
# Staff                                  9.000000           10.000000
# Atmosphere                             8.000000            8.000000
# Cleanliness                           10.000000            8.000000
# Value for Money                        9.000000           10.000000
# Facilities                             9.000000           10.000000
# avg                                    9.285714            8.857143
#
#                  Ayenda Oasis Airport  Roomies Hostel Centro Medico  \
# Security                    10.000000                      8.300000
# Location                     8.000000                      9.700000
# Staff                       10.000000                      9.400000
# Atmosphere                   8.000000                      7.700000
# Cleanliness                 10.000000                      7.400000
# Value for Money              8.000000                      8.300000
# Facilities                   8.000000                      7.400000
# avg                          8.857143                      8.314286
#
#                  Hotel Amigo Suites Downtown  Cadillac Boutique Hotel  \
# Security                            9.200000                 8.700000
# Location                            9.200000                 7.300000
# Staff                               9.200000                 9.300000
# Atmosphere                          6.400000                 5.300000
# Cleanliness                         8.000000                10.000000
# Value for Money                     7.600000                 4.700000
# Facilities                          6.800000                 7.300000
# avg                                 8.057143                 7.514286
#
#                  Anys Hostal  B&B Mexico Roma Norte
# Security           10.000000               9.800000
# Location           10.000000               9.800000
# Staff              10.000000               9.300000
# Atmosphere         10.000000               8.200000
# Cleanliness        10.000000               9.300000
# Value for Money    10.000000               8.600000
# Facilities          9.600000               7.800000
# avg                 9.942857               8.971429
#
# [8 rows x 46 columns]

# %%
avg_info = df_test.sort_values(by='avg', ascending=False)
figure = plt.figure(figsize=(10,6))
sns.barplot(y=avg_info.name, x=avg_info.ratings)
plt.xticks()
plt.xlabel('Ratings')
plt.ylabel('Hostel Name')
plt.title('Top 20 Hostels by Ratings')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/viminnanavati/Desktop/Data_Science_App/Projects/Portfolio/Web_Scraping/Mexico.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/viminnanavati/Desktop/Data_Science_App/Projects/Portfolio/Web_Scraping/Mexico.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> avg_info = df_test.sort_values(by='avg', ascending=False)
#       <a href='vscode-notebook-cell:/Users/viminnanavati/Desktop/Data_Science_App/Projects/Portfolio/Web_Scraping/Mexico.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> figure = plt.figure(figsize=(10,6))
#       <a href='vscode-notebook-cell:/Users/viminnanavati/Desktop/Data_Science_App/Projects/Portfolio/Web_Scraping/Mexico.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> sns.barplot(y=avg_info.name, x=avg_info.ratings)
#
# File ~/opt/anaconda3/envs/snowflakes/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/snowflakes/lib/python3.10/site-packages/pandas/core/frame.py:6904, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6900 elif len(by):
#    6901     # len(by) == 1
#    6903     by = by[0]
# -> 6904     k = self._get_label_or_level_values(by, axis=axis)
#    6906     # need to rewrap column in Series to apply key function
#    6907     if key is not None:
#    6908         # error: Incompatible types in assignment (expression has type
#    6909         # "Series", variable has type "ndarray")
#
# File ~/opt/anaconda3/envs/snowflakes/lib/python3.10/site-packages/pandas/core/generic.py:1849, in NDFrame._get_label_or_level_values(self, key, axis)
#    1843     values = (
#    1844         self.axes[axis]
#    1845         .get_level_values(key)  # type: ignore[assignment]
#    1846         ._values
#    1847     )
#    1848 else:
# -> 1849     raise KeyError(key)
#    1851 # Check for duplicates
#    1852 if values.ndim > 1:
#
# KeyError: 'avg'
